# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('C:/Users/ekans/Downloads/archive/PopularMovies.csv')

# %%
df
# Out:
#      Unnamed: 0               Movie_Names  Ratings  Released_Year  \
# 0             0  The Shawshank Redemption      9.2           1994
# 1             1             The Godfather      9.2           1972
# 2             2           The Dark Knight      9.0           2008
# 3             3     The Godfather Part II      9.0           1974
# 4             4              12 Angry Men      9.0           1957
# ..          ...                       ...      ...            ...
# 245         245                  The Help      8.0           2011
# 246         246             Life of Brian      8.0           1979
# 247         247            The Iron Giant      8.0           1999
# 248         248                   Aladdin      8.0           1992
# 249         249        Dances with Wolves      8.0           1990
#
#                                             Movie_Link  \
# 0    https://www.imdb.com/title/tt0111161/?pf_rd_m=...
# 1    https://www.imdb.com/title/tt0068646/?pf_rd_m=...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0               Movie_Names  Ratings  Released_Year  \
# 0           0  The Shawshank Redemption      9.2           1994
# 1           1             The Godfather      9.2           1972
# 2           2           The Dark Knight      9.0           2008
# 3           3     The Godfather Part II      9.0           1974
# 4           4              12 Angry Men      9.0           1957
#
#                                           Movie_Link  \
# 0  https://www.imdb.com/title/tt0111161/?pf_rd_m=...
# 1  https://www.imdb.com/title/tt0068646/?pf_rd_m=...
# 2  https://www.imdb.com/title/tt0468569/?pf_rd_m=...
# 3  https://www.imdb.com/title/tt0071562/?pf_rd_m=...
# 4  https://www.imdb.com/title/tt0050083/?pf_rd_m=...
#
#                                           Votes  Metascore Userreviews  \
# 0  <div class="sc-bde20123-3 bjjENQ">2.8M</div>         82       10.9K
# 1  <div class="sc-bde20123-3 bjjENQ">1.9M</div>        100        5.4K
# ...

# %%
high_reviews = (df['Userreviews']>'7K')

# %%
df.loc[high_reviews,['Movie_Names','Ratings']]
# Out:
#                                      Movie_Names  Ratings
# 2                                The Dark Knight      9.0
# 10           Spider-Man: Across the Spider-Verse      8.8
# 21                                 Seven Samurai      8.6
# 44                        Grave of the Fireflies      8.5
# 46                              The Intouchables      8.5
# 48                  Once Upon a Time in the West      8.4
# 50                                   Rear Window      8.4
# 78                             Avengers: Endgame      8.3
# 79                             Princess Mononoke      8.3
# 81                   Once Upon a Time in America      8.3
# 83                                      3 Idiots      8.3
# 88                                   Toy Story 3      8.3
# 89    Star Wars: Episode VI - Return of the Jedi      8.3
# 105                            Full Metal Jacket      8.2
# 115                            L.A. Confidential      8.2
# ...

# %%
specific_rating = [9.0,9.1]
filt1 = df['Ratings'].isin(specific_rating)

# %%
df.loc[filt1,'Movie_Names']
# Out:
# 2          The Dark Knight
# 3    The Godfather Part II
# 4             12 Angry Men
# Name: Movie_Names, dtype: object

# %%
df['Ratings']
